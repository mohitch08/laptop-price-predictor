# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/campusx-official/laptop-price-predictor-regression-project/main/laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\MOHIT\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\MOHIT\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232            0    0
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Ips', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 901     Asus              Gaming    17.3
# 679     Acer              Gaming    15.6
# 1289    Asus           Ultrabook    13.3
# 1194    Dell  2 in 1 Convertible    13.3
# 757       HP         Workstation    15.6
#
#                                ScreenResolution                          Cpu  \
# 901                 IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz
# 679                           Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 1289                IPS Panel Full HD 1920x1080     Intel Core M 6Y30 0.9GHz
# 1194  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i5 7200U 2.5GHz
# 757                           Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz
#
#      Ram                  Memory                         Gpu       OpSys  \
# 901   32  256GB SSD +  256GB SSD     Nvidia GeForce GTX 980M  Windows 10
# 679   16               256GB SSD  Nvidia GeForce GTX 1050 Ti  Windows 10
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float64(2), int32(2), int64(2), object(9)
# ...

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz   8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz              190
# Intel Core i7 7700HQ 2.8GHz             146
# Intel Core i7 7500U 2.7GHz              134
# Intel Core i7 8550U 1.8GHz               73
# Intel Core i5 8250U 1.6GHz               72
#                                        ...
# Intel Core i5 6260U 1.8GHz                1
# Intel Core M m3-7Y30 2.2GHz               1
# Intel Pentium Dual Core N4200 1.1GHz      1
# Intel Pentium Dual Core 4405Y 1.5GHz      1
# Intel Core i5 7200U 2.70GHz               1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz   8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080            0    1
#
#           ppi       Cpu Name
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook   8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook   8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook   8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook  16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook   8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys Weight        Price  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS   1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS   1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS   1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS   1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS   1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# <ipython-input-49-10829db803de>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# <ipython-input-49-10829db803de>:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.sample(5)
# Out:
#      Company   TypeName Ram    Memory                    Gpu       OpSys  \
# 1044      HP   Notebook   4   500 HDD  Intel HD Graphics 520  Windows 10
# 68    Lenovo   Notebook   4  1000 HDD  Intel HD Graphics 620  Windows 10
# 849       HP  Ultrabook   8   512 SSD  Intel HD Graphics 520  Windows 10
# 997     Acer   Notebook   4   500 HDD  Intel HD Graphics 505  Windows 10
# 386   Lenovo   Notebook   4   128 SSD  Intel HD Graphics 620  Windows 10
#
#      Weight     Price  Touchscreen  Ips         ppi              Cpu brand  \
# 1044   1.54  53280.00            0    0  157.350512          Intel Core i5
# 68      1.9  29250.72            0    0  141.211998          Intel Core i5
# 849    1.54  78215.04            0    0  157.350512          Intel Core i7
# 997     2.4  20246.40            0    0  100.454670  Other Intel Processor
# 386     1.5  29250.72            0    1  165.632118          Intel Core i3
#
#        HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.corr()['Price']
# Out:
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Ram                           Gpu  OpSys Weight  \
# 0   Apple  Ultrabook   8  Intel Iris Plus Graphics 640  macOS   1.37
# 1   Apple  Ultrabook   8        Intel HD Graphics 6000  macOS   1.34
# 2      HP   Notebook   8         Intel HD Graphics 620  No OS   1.86
# 3   Apple  Ultrabook  16            AMD Radeon Pro 455  macOS   1.83
# 4   Apple  Ultrabook   8  Intel Iris Plus Graphics 650  macOS   1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R7 M360           1
# AMD Radeon R5 M315           1
# AMD FirePro W6150M           1
# Nvidia GTX 980 SLI           1
# AMD Radeon R9 M385           1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName Ram                           Gpu  OpSys Weight  \
# 0   Apple  Ultrabook   8  Intel Iris Plus Graphics 640  macOS   1.37
# 1   Apple  Ultrabook   8        Intel HD Graphics 6000  macOS   1.34
# 2      HP   Notebook   8         Intel HD Graphics 620  No OS   1.86
# 3   Apple  Ultrabook  16            AMD Radeon Pro 455  macOS   1.83
# 4   Apple  Ultrabook   8  Intel Iris Plus Graphics 650  macOS   1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Ram  OpSys Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook   8  macOS   1.37   71378.6832            0    1
# 1   Apple  Ultrabook   8  macOS   1.34   47895.5232            0    0
# 2      HP   Notebook   8  No OS   1.86   30636.0000            0    0
# 3   Apple  Ultrabook  16  macOS   1.83  135195.3360            0    1
# 4   Apple  Ultrabook   8  macOS   1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Ram Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook   8   1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook   8   1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook   8   1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook  16   1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook   8   1.37   96095.8080            0    1  226.983005
#
#        Cpu brand  HDD  SSD Gpu brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\MOHIT\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Price'>

# %%
df.corr()['Price']
# Out:
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\MOHIT\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName Ram Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook   8    2.0            0    0  100.454670
# 1141      MSI              Gaming   8    2.4            0    0  141.211998
# 1049     Asus             Netbook   4    1.2            0    0  135.094211
# 1020     Dell  2 in 1 Convertible   4   2.08            1    1  141.211998
# 878      Dell            Notebook   4   2.18            0    0  141.211998
# ...       ...                 ...  ..    ...          ...  ...         ...
# 466      Acer            Notebook   4    2.2            0    0  100.454670
# 299      Asus           Ultrabook  16   1.63            0    0  141.211998
# 493      Acer            Notebook   8    2.2            0    0  100.454670
# 527    Lenovo            Notebook   8    2.2            0    0  100.454670
# 1193    Apple           Ultrabook   8  0.920            0    1  226.415547
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# ...

# %%
y_train
# Out:
# 183     10.651384
# 1141    11.016798
# 1049     9.638174
# 1020    10.655148
# 878     10.791749
#           ...
# 466     10.126164
# 299     11.267217
# 493     10.336864
# 527     10.104611
# 1193    11.034319
# Name: Price, Length: 1106, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# # linear regression

# %%
step1=ColumnTransformer([('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11]),
                     ('scale',StandardScaler(),[2,3,4,5,6,8,9])],remainder='passthrough')

# %%
step2=LinearRegression()

# %%
pipe=Pipeline([('step1',step1),
              ('step2',step2)])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   [0, 1, 7, 10, 11]),
#                                                  ('scale', StandardScaler(),
#                                                   [2, 3, 4, 5, 6, 8, 9])])),
#                 ('step2', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)

# %%
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073277450155072
# MAE 0.21017827953019036

# %% [markdown]
# # rigde Regression

# %%
step1=ColumnTransformer([('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11]),
                     ('scale',StandardScaler(),[2,3,4,5,6,8,9])],remainder='passthrough')
step2 = Ridge(alpha=10)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8121638718072757
# MAE 0.20951207415927586

# %% [markdown]
# # Lasso Regression

# %%
step1=ColumnTransformer([('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11]),
                     ('scale',StandardScaler(),[2,3,4,5,6,8,9])],remainder='passthrough')
step2 = Lasso(alpha=0.001)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8069463726220182
# MAE 0.21122025499340125

# %% [markdown]
# # Decision Tree

# %%
step1=ColumnTransformer([('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11]),
                     ('scale',StandardScaler(),[2,3,4,5,6,8,9])],remainder='passthrough')
step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8440478624793242
# MAE 0.18090525604308683

# %% [markdown]
# # Random Forest

# %%
step1=ColumnTransformer([('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11]),
                     ('scale',StandardScaler(),[2,3,4,5,6,8,9])],remainder='passthrough')
step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8874438599362796
# MAE 0.15875485888541058

# %%
# tunning hyperparameters of random forest by gridsearchCV

# %%
params={'step2__n_estimators':[100,120,135,110],
       'step2__max_samples':[0.5,0.75,0.9],
       'step2__max_features':[0.5,0.75,0.9],
       'step2__max_depth':[10,12,15,20]}

# %%
gs=GridSearchCV(estimator=pipe,param_grid=params,cv=4,n_jobs=-1)

# %%
gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=4,
#              estimator=Pipeline(steps=[('step1',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('col_tnf',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse=False),
#                                                                          [0, 1,
#                                                                           7, 10,
#                                                                           11]),
#                                                                         ('scale',
#                                                                          StandardScaler(),
#                                                                          [2, 3,
# ...

# %%
gs.best_params_
# Out:
# {'step2__max_depth': 15,
#  'step2__max_features': 0.5,
#  'step2__max_samples': 0.9,
#  'step2__n_estimators': 135}

# %%
pd.DataFrame(gs.cv_results_).sort_values(by='rank_test_score').head()
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 82        0.902132      0.047349         0.054674        0.007811
# 128       0.706865      0.017023         0.042959        0.006764
# 81        0.808403      0.044699         0.050769        0.006764
# 129       0.835741      0.023432         0.042958        0.006764
# 131       0.773255      0.028162         0.035148        0.006765
#
#     param_step2__max_depth param_step2__max_features param_step2__max_samples  \
# 82                      15                       0.5                      0.9
# 128                     20                      0.75                      0.9
# 81                      15                       0.5                      0.9
# 129                     20                      0.75                      0.9
# 131                     20                      0.75                      0.9
#
#     param_step2__n_estimators  \
# 82                        135
# 128                       100
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df=df.drop('Unnamed: 0',axis=1)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
# getting insights about each columns

# %%
df.Company.value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# LG             3
# Chuwi          3
# Fujitsu        3
# Google         3
# Huawei         2
# Name: Company, dtype: int64

# %%
df['TypeName'].value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# Touchscreen 2256x1504                              6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# ...

# %%
def screen_type(inp):
    if 'Touchscreen' in inp:
        return 'Touchscreen'
    else:
        return 'IPS'

# %%
df['screen_type']=df['ScreenResolution'].apply(screen_type)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
def x_dim(inp):
    x=inp.split('x')[0].split()[-1]
    return int(x)

# %%
def y_dim(inp):
    y=inp.split('x')[1]
    return int(y)

# %%
df['x_res']=df['ScreenResolution'].apply(x_dim)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price screen_type x_res
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832         IPS  1600
# ...

# %%
df['y_res']=df['ScreenResolution'].apply(y_dim)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price screen_type x_res  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832         IPS  1600
# ...

# %%
df=df.drop('ScreenResolution',axis=1)
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#          Price screen_type x_res  y_res
# 0   71378.6832         IPS  1600   1600
# 1   47895.5232         IPS   900    900
# 2   30636.0000         IPS  1080   1080
# ...

# %%
df['Cpu'].unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Atom x5-Z8350 1.44GHz',
#        'Intel Core i5 7300HQ 2.5GHz', 'AMD E-Series E2-9000e 1.5GHz',
#        'Intel Core i5 1.6GHz', 'Intel Core i7 8650U 1.9GHz',
#        'Intel Atom x5-Z8300 1.44GHz', 'AMD E-Series E2-6110 1.5GHz',
#        'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
# ...

# %%
def processor(inp):
    if 'Intel Core i5' in inp:
        return 'Intel Core i5'
    if 'Intel Core i3' in inp:
        return 'Intel Core i3'
    if 'Intel Core i7' in inp:
        return 'Intel Core i7'
    if 'AMD' in inp:
        return 'AMD'
    else:
        return 'Intel'

# %%
df['processor']=df['Cpu'].apply(processor)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...

# %%
s='Intel Celeron Dual Core N3050 1.6GHz'

# %%
s.split('GHz')[0].split()[-1]
# Out:
# '1.6'

# %%
def cpu_speed(inp):
    return float(inp.split('GHz')[0].split()[-1])

# %%
df['cpu_speed']=df['Cpu'].apply(cpu_speed)
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#          Price screen_type x_res  y_res      processor  cpu_speed
# 0   71378.6832         IPS  1600   1600  Intel Core i5        2.3
# ...

# %%
df=df.drop('Cpu',axis=1)
df.head()
# Out:
#   Company   TypeName  Inches   Ram               Memory  \
# 0   Apple  Ultrabook    13.3   8GB            128GB SSD
# 1   Apple  Ultrabook    13.3   8GB  128GB Flash Storage
# 2      HP   Notebook    15.6   8GB            256GB SSD
# 3   Apple  Ultrabook    15.4  16GB            512GB SSD
# 4   Apple  Ultrabook    13.3   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price screen_type x_res  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832         IPS  1600
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232         IPS   900
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000         IPS  1080
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360         IPS  1800
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080         IPS  1600
#
#    y_res      processor  cpu_speed
# 0   1600  Intel Core i5        2.3
# 1    900  Intel Core i5        1.8
# 2   1080  Intel Core i5        2.5
# ...

# %%
df.Ram.value_counts()
# Out:
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: Ram, dtype: int64

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df.Ram.astype(int)
df.head()
# Out:
#   Company   TypeName  Inches Ram               Memory  \
# 0   Apple  Ultrabook    13.3   8            128GB SSD
# 1   Apple  Ultrabook    13.3   8  128GB Flash Storage
# 2      HP   Notebook    15.6   8            256GB SSD
# 3   Apple  Ultrabook    15.4  16            512GB SSD
# 4   Apple  Ultrabook    13.3   8            256GB SSD
#
#                             Gpu Weight        Price screen_type x_res  y_res  \
# 0  Intel Iris Plus Graphics 640   1.37   71378.6832         IPS  1600   1600
# 1        Intel HD Graphics 6000   1.34   47895.5232         IPS   900    900
# 2         Intel HD Graphics 620   1.86   30636.0000         IPS  1080   1080
# 3            AMD Radeon Pro 455   1.83  135195.3360         IPS  1800   1800
# 4  Intel Iris Plus Graphics 650   1.37   96095.8080         IPS  1600   1600
#
#        processor  cpu_speed      OS
# 0  Intel Core i5        2.3     Mac
# 1  Intel Core i5        1.8     Mac
# 2  Intel Core i5        2.5  others
# ...

# %%
df.Memory.value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 512GB Flash Storage                2
# 256GB SSD +  256GB SSD             2
# 256GB SSD +  500GB HDD             2
# ...

# %%
s='512GB SSD +  2TB HDD'

# %%
if 'SSD' in s:
    s.split('SSD')

# %%
s.split('HDD')
# Out:
# ['512GB SSD +  2TB ', '']

# %%
df.head()
# Out:
#   Company   TypeName  Inches Ram               Memory  \
# 0   Apple  Ultrabook    13.3   8            128GB SSD
# 1   Apple  Ultrabook    13.3   8  128GB Flash Storage
# 2      HP   Notebook    15.6   8            256GB SSD
# 3   Apple  Ultrabook    15.4  16            512GB SSD
# 4   Apple  Ultrabook    13.3   8            256GB SSD
#
#                             Gpu Weight        Price screen_type x_res  y_res  \
# 0  Intel Iris Plus Graphics 640   1.37   71378.6832         IPS  1600   1600
# 1        Intel HD Graphics 6000   1.34   47895.5232         IPS   900    900
# 2         Intel HD Graphics 620   1.86   30636.0000         IPS  1080   1080
# 3            AMD Radeon Pro 455   1.83  135195.3360         IPS  1800   1800
# 4  Intel Iris Plus Graphics 650   1.37   96095.8080         IPS  1600   1600
#
#        processor  cpu_speed      OS
# 0  Intel Core i5        2.3     Mac
# 1  Intel Core i5        1.8     Mac
# 2  Intel Core i5        2.5  others
# ...

# %%
df.Weight=df['Weight'].str.replace('kg','')

# %%
df.Weight.astype('float32')
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1298    1.80
# 1299    1.30
# 1300    1.50
# 1301    2.19
# 1302    2.20
# Name: Weight, Length: 1303, dtype: float32

# %%
df.sample(5)
# Out:
#       Company            TypeName  Inches Ram                Memory  \
# 491   Toshiba           Ultrabook    13.3  32             512GB SSD
# 1069    Apple           Ultrabook    12.0   8   256GB Flash Storage
# 1260   Lenovo  2 in 1 Convertible    14.0   4             128GB SSD
# 121       MSI              Gaming    15.6  16  256GB SSD +  2TB HDD
# 95       Acer  2 in 1 Convertible    13.3   8             256GB SSD
#
#                           Gpu Weight        Price  screen_type x_res  y_res  \
# 491     Intel HD Graphics 620   1.05  149130.7200  Touchscreen  1080   1080
# 1069    Intel HD Graphics 515  0.920   69264.0000          IPS  1440   1440
# 1260    Intel HD Graphics 520    1.8   44382.7728  Touchscreen  1080   1080
# 121   Nvidia GeForce GTX 1070    1.8  119427.1200          IPS  1080   1080
# 95     Intel UHD Graphics 620    1.5   45128.1600  Touchscreen  1080   1080
#
#           processor  cpu_speed       OS
# 491   Intel Core i7        2.7  Windows
# ...

# %%
def OS(inp):
    if inp=='Windows 10' or inp=='Windows 7' or inp=='Windows 10 S':
        return 'Windows'
    if inp=='macOS'or inp=='Mac OS X':
        return 'Mac'
    else:
        return 'others'

# %%
df['OS']=df['OpSys'].apply(OS)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OpSys'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-a02dacda9e5e> in <module>
# ----> 1 df['OS']=df['OpSys'].apply(OS)
# ...

# %%
df=df.drop('OpSys',axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-1bcc9b14b812> in <module>
# ----> 1 df=df.drop('OpSys',axis=1)
#       2 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Inches Ram               Memory  \
# 0   Apple  Ultrabook    13.3   8            128GB SSD
# 1   Apple  Ultrabook    13.3   8  128GB Flash Storage
# 2      HP   Notebook    15.6   8            256GB SSD
# 3   Apple  Ultrabook    15.4  16            512GB SSD
# 4   Apple  Ultrabook    13.3   8            256GB SSD
#
#                             Gpu Weight        Price screen_type x_res  y_res  \
# 0  Intel Iris Plus Graphics 640   1.37   71378.6832         IPS  1600   1600
# 1        Intel HD Graphics 6000   1.34   47895.5232         IPS   900    900
# 2         Intel HD Graphics 620   1.86   30636.0000         IPS  1080   1080
# 3            AMD Radeon Pro 455   1.83  135195.3360         IPS  1800   1800
# 4  Intel Iris Plus Graphics 650   1.37   96095.8080         IPS  1600   1600
#
#        processor  cpu_speed      OS
# 0  Intel Core i5        2.3     Mac
# 1  Intel Core i5        1.8     Mac
# 2  Intel Core i5        2.5  others
# ...

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620       281
# Intel HD Graphics 520       185
# Intel UHD Graphics 620       68
# Nvidia GeForce GTX 1050      66
# Nvidia GeForce GTX 1060      48
#                            ...
# AMD FirePro W4190M            1
# Nvidia Quadro 3000M           1
# AMD FirePro W6150M            1
# Nvidia GeForce GTX 930MX      1
# AMD FirePro W5130M            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['gpu_brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches Ram               Memory  \
# 0   Apple  Ultrabook    13.3   8            128GB SSD
# 1   Apple  Ultrabook    13.3   8  128GB Flash Storage
# 2      HP   Notebook    15.6   8            256GB SSD
# 3   Apple  Ultrabook    15.4  16            512GB SSD
# 4   Apple  Ultrabook    13.3   8            256GB SSD
#
#                             Gpu Weight        Price screen_type x_res  y_res  \
# 0  Intel Iris Plus Graphics 640   1.37   71378.6832         IPS  1600   1600
# 1        Intel HD Graphics 6000   1.34   47895.5232         IPS   900    900
# 2         Intel HD Graphics 620   1.86   30636.0000         IPS  1080   1080
# 3            AMD Radeon Pro 455   1.83  135195.3360         IPS  1800   1800
# 4  Intel Iris Plus Graphics 650   1.37   96095.8080         IPS  1600   1600
#
#        processor  cpu_speed      OS gpu_brand
# 0  Intel Core i5        2.3     Mac     Intel
# 1  Intel Core i5        1.8     Mac     Intel
# ...

# %%
df.drop('Gpu',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches Ram               Memory Weight        Price  \
# 0   Apple  Ultrabook    13.3   8            128GB SSD   1.37   71378.6832
# 1   Apple  Ultrabook    13.3   8  128GB Flash Storage   1.34   47895.5232
# 2      HP   Notebook    15.6   8            256GB SSD   1.86   30636.0000
# 3   Apple  Ultrabook    15.4  16            512GB SSD   1.83  135195.3360
# 4   Apple  Ultrabook    13.3   8            256GB SSD   1.37   96095.8080
#
#   screen_type x_res  y_res      processor  cpu_speed      OS gpu_brand
# 0         IPS  1600   1600  Intel Core i5        2.3     Mac     Intel
# 1         IPS   900    900  Intel Core i5        1.8     Mac     Intel
# 2         IPS  1080   1080  Intel Core i5        2.5  others     Intel
# 3         IPS  1800   1800  Intel Core i7        2.7     Mac       AMD
# 4         IPS  1600   1600  Intel Core i5        3.1     Mac     Intel

# %% [markdown]
# # feature engg in 'memory' column

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 512GB Flash Storage                2
# 256GB SSD +  256GB SSD             2
# 256GB SSD +  500GB HDD             2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df['Memory']=df['Memory'].str.replace('TB','000')
df['Memory']=df['Memory'].str.replace('GB','')
df.Memory.value_counts()
# Out:
# 256 SSD                         412
# 1000 HDD                        224
# 500 HDD                         132
# 512 SSD                         118
# 128 SSD +  1000 HDD              94
# 128 SSD                          76
# 256 SSD +  1000 HDD              73
# 32 Flash Storage                 38
# 2000 HDD                         16
# 64 Flash Storage                 15
# 512 SSD +  1000 HDD              14
# 1000 SSD                         14
# 256 SSD +  2000 HDD              10
# 1000 Hybrid                       9
# 256 Flash Storage                 8
# 16 Flash Storage                  7
# 32 SSD                            6
# 180 SSD                           5
# 128 Flash Storage                 4
# 16 SSD                            3
# 512 SSD +  2000 HDD               3
# 256 SSD +  256 SSD                2
# 128 SSD +  2000 HDD               2
# 256 SSD +  500 HDD                2
# 1000 SSD +  1000 HDD              2
# 512 Flash Storage                 2
# ...

# %%
s.split()
